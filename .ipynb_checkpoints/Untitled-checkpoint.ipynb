# %%
import pandas as pd
url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/tic-tac-toe/tic-tac-toe.data'

myCols = ['col1', 'col2', 'col3', 'col4', 'col5', 'col6', 'col7', 'col8', 'col9', 'col10']

df = pd.read_csv(url, names = myCols)

# %%
df.head()
# Out:
#   col1 col2 col3 col4 col5 col6 col7 col8 col9     col10
# 0    x    x    x    x    o    o    x    o    o  positive
# 1    x    x    x    x    o    o    o    x    o  positive
# 2    x    x    x    x    o    o    o    o    x  positive
# 3    x    x    x    x    o    o    o    b    b  positive
# 4    x    x    x    x    o    o    b    o    b  positive

# %%
url_mms = 'https://tinyurl.com/mms-statistics'

df = pd.read_csv(url_mms)

df.shape
# Out:
# (816, 4)

# %%
df.head()
# Out:
#             type   color  diameter  mass
# 0  peanut butter    blue     16.20  2.18
# 1  peanut butter   brown     16.50  2.01
# 2  peanut butter  orange     15.48  1.78
# 3  peanut butter   brown     16.32  1.98
# 4  peanut butter  yellow     15.59  1.62

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   type      816 non-null    object
#  1   color     816 non-null    object
#  2   diameter  816 non-null    float64
#  3   mass      816 non-null    float64
# dtypes: float64(2), object(2)
# memory usage: 25.6+ KB

# %%
df.describe()
# Out:
#          diameter        mass
# count  816.000000  816.000000
# mean    14.171912    1.419632
# std      1.220001    0.714765
# min     11.230000    0.720000
# 25%     13.220000    0.860000
# 50%     13.600000    0.920000
# 75%     15.300000    1.930000
# max     17.880000    3.620000

# %%
df.columns
# Out:
# Index(['type', 'color', 'diameter', 'mass'], dtype='object')

# %%
df.drop(columns='mass').head()
# Out:
#             type   color  diameter
# 0  peanut butter    blue     16.20
# 1  peanut butter   brown     16.50
# 2  peanut butter  orange     15.48
# 3  peanut butter   brown     16.32
# 4  peanut butter  yellow     15.59

# %%
df['type'].value_counts()
# Out:
# plain            462
# peanut butter    201
# peanut           153
# Name: type, dtype: int64

# %%
df.isnull().sum()
# Out:
# type        0
# color       0
# diameter    0
# mass        0
# dtype: int64

# %%
df.sort_values(by = 'diameter')
# Out:
#               type   color  diameter  mass
# 616          plain   green     11.23  0.73
# 634          plain   green     12.15  0.85
# 324          plain  yellow     12.32  0.72
# 568          plain   brown     12.38  0.82
# 271          plain    blue     12.39  0.81
# ..             ...     ...       ...   ...
# 5    peanut butter   brown     17.43  2.59
# 118  peanut butter    blue     17.43  2.54
# 84   peanut butter     red     17.50  2.53
# 143  peanut butter   green     17.61  2.63
# 785         peanut    blue     17.88  3.57
#
# [816 rows x 4 columns]

# %%
import numpy as np
df = pd.DataFrame({
   'planets': ['Mercury', 'Venus', 'Earth', 'Mars', 'Jupiter', 
   'Saturn', 'Uranus', 'Neptune', 'Pluto'],
   'distance': [0.4, 0.7, 1, 1.5, 5.2, 9.6, 19.2, 30, 39.5]
   }, index=[1, 2, 3, 4, 5, 6, 7, 8, 9])
df.head()
# Out:
#    planets  distance
# 1  Mercury       0.4
# 2    Venus       0.7
# 3    Earth       1.0
# 4     Mars       1.5
# 5  Jupiter       5.2

# %%
df.plot.line()
# Out:
# <AxesSubplot:>

# %%
df = pd.DataFrame(np.random.randint(0, 100, size=(100, 1)))
df.plot.hist(bins = 10)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df = pd.DataFrame(np.random.rand(50, 2), columns = ['a', 'b'])
df.plot.scatter(x = 'a', y = 'b')
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
numbers = pd.Series([1, 2, 2.5, 3, 3.5, 4, 5])
numbers.plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
import matplotlib.pyplot as plt
import numpy as np
# print(plt.style.available)

# set style-sheet
plt.style.use('seaborn-bright')
# create x var
x = np.linspace(0, 10)
# create figure and aces objects
fig, ax = plt.subplots(figsize=(8, 8))
# plot random data
ax.plot(x, np.sin(x) + x + np.random.randn(50))
ax.plot(x, np.sin(x) + 0.5 * x + np.random.randn(50))
ax.plot(x, np.sin(x) + 2 * x + np.random.randn(50))
ax.plot(x, np.sin(x) - 0.5 * x + np.random.randn(50))
ax.plot(x, np.sin(x) + np.random.randn(50))
ax.set_title("'seaborn-bright' style sheet");

# plt.clf()

# %%
plt.style.use('dark_background')

fig, ax = plt.subplots(figsize=(8,8))

ax.plot(x, np.sin(x) + x + np.random.randn(50))
ax.plot(x, np.sin(x) + 0.5 * x + np.random.randn(50))
ax.plot(x, np.sin(x) + 2 * x + np.random.randn(50))
ax.plot(x, np.sin(x) - 0.5 * x + np.random.randn(50))
ax.plot(x, np.sin(x) + np.random.randn(50))
ax.set_title("'dark_background' style sheet");

# %%
# generate the x and multiple y vals
X = np.linspace(0.5, 3.5, 100)
Y1 = 3 + np.cos(X)
Y2 = 1 + np.cos(1 + X / 0.75) / 2
Y3 = np.random.uniform(Y1, Y2, len(X))
# create the figure object with a size of 8x8 inches
fig = plt.figure(figsize = (8, 8))
# create the figure axes with a single plot
ax = fig.add_subplot(1, 1 , 1)
# finally, plot! choosing different colors
# plot magenta line, width = 2
ax.plot(X, Y1, c = 'm', lw = 2, label = 'magenta signal')
# plot orange dash-dot lin, width = 3
ax.plot(X, Y2, c = 'orange', lw = 3, linestyle = '-.', label = 'orange signal')
# plot yellow circle markers with a green edge, line width = 0 (not visible)
ax.plot(X, Y3, linewidth = 0, marker = 'o', markerfacecolor = 'y', markeredgecolor = 'g')
# set title and x and y axis labels
ax.set_title('Anatomy of a figure (modified)', fontsize = 18)
ax.set_xlabel('X axis label')
ax.set_ylabel('Y axis label')
# plot the legend using the labels defined
ax.legend()
# show
plt.show()

# %%
# create x axis data
x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.cos(x)
# create plot figure
plt.figure(figsize = (8, 8))
# create top subplot (plot within a plot), (2 rows, 1 col, pos 1)
plt.subplot (2, 1, 1)
plt.plot(x, y1, color = 'b')
# create bot subplot, (2 rows, 1 col, pos 2)
plt.subplot(2, 1, 2)
plt.plot(x, y2, color = 'orange')
# add title to figure (not subplots)
plt.suptitle('Pyplot Interface Example')
# show
plt.show()

# %%
# same data as above
# create a grid of plots (notice 's' in subplots), (figure, ax - two axes objects)
fig, ax = plt.subplots(2, figsize = (8, 8))
# look at size of ax
print('Number of axes created: ', ax.size)
# call plot() method on each axes object
# object 1
ax[0].plot(x, y1, 'b')
# object 2
ax[1].plot(x, y2, color = 'orange')
# add a title to the top axes object
ax[0].set_title('Object-oriented Interface Example')
# show
# fig.clf()
fig.show()
# Out:
# Number of axes created:  2
# C:\Users\jeffkang\AppData\Local\Temp/ipykernel_1684/878872767.py:15: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
